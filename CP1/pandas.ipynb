# %%
import pandas as pd

df1 = pd.read_csv('glauber.csv')
df1.head()
df2 = pd.read_csv('kawasaki.csv')
df2.head()
# Out:
#    Unnamed: 0         T        E        M        Hc    Hc_err      Msus  \
# 0           0  1.000000 -4993.08  2498.26  0.018797  0.003041  0.001205
# 1           1  1.105263 -4984.88  2496.14  0.037677  0.005387  0.002729
# 2           2  1.210526 -4969.04  2491.90  0.064081  0.007996  0.005746
# 3           3  1.315789 -4941.64  2484.58  0.145137  0.022512  0.014721
# 4           4  1.421053 -4910.68  2475.96  0.143572  0.017761  0.016461
#
#    Msus_err
# 0  0.000196
# 1  0.000390
# 2  0.000727
# 3  0.002517
# 4  0.001936

# %%
import matplotlib.pyplot as plt

# %%
plt.errorbar(df1['T'],df1['Hc'], df1['Hc_err'])
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.errorbar(df2['T'],df2['Hc'], df2['Hc_err'])
# Out:
# <ErrorbarContainer object of 3 artists>
